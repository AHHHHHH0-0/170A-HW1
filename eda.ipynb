# %%
from pathlib import Path
import pandas as pd 

names = [
    'acm_fellows', 
    'conference_ranking', 
    'country_info', 
    'csrankings', 
    'data', 
    'dblp_alias', 
    'field_conference', 
    'generated_author_info', 
    'geo_location', 
    'turing'
]

# Load files
dir = Path('data/')
files = {name:pd.read_csv(file) for name, file in zip(names, dir.iterdir())}

# %%
# First 3 rows of each file 
for file in files:
    print('-'*100)
    print(file)
    print('-'*100)
    print(files[file].head(3))
    print()
# Out:
# ----------------------------------------------------------------------------------------------------
# acm_fellows
# ----------------------------------------------------------------------------------------------------
#              name  year
# 0    A. J. Milner  1994
# 1  Aaron Finerman  1994
# 2  Adele Goldberg  1994
#
# ----------------------------------------------------------------------------------------------------
# conference_ranking
# ----------------------------------------------------------------------------------------------------
#           institution  region countryabbrv
# 0                AUEB  europe           gr
# 1  Aalborg University  europe           dk
# 2    Aalto University  europe           fi
#
# ----------------------------------------------------------------------------------------------------
# country_info
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# First file 
f1 = names[0]
file = files[f1]

print(f1)
print()
print(file.head())
print()
print(file.describe())
print()
print(file.isnull().sum())
# Out:
# acm_fellows
#
#               name  year
# 0     A. J. Milner  1994
# 1   Aaron Finerman  1994
# 2   Adele Goldberg  1994
# 3     Allen Tucker  1994
# 4  Andries van Dam  1994
#
#               year
# count  1493.000000
# mean   2009.217683
# std       9.650052
# min    1994.000000
# 25%    2000.000000
# 50%    2010.000000
# 75%    2018.000000
# max    2023.000000
#
# name    0
# year    0
# dtype: int64
